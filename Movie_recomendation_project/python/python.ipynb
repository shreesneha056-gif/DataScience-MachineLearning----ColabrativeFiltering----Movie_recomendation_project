# %%
import pandas as pd
import numpy as np
from sklearn.metrics import pairwise_distances

# %%
data_user = pd.read_csv(r'C:\Users\sneha\anaconda assignment\excel\u .data',delimiter = "\t", header = None)

# %%
data_user
# Out:
#          0     1  2          3
# 0      196   242  3  881250949
# 1      186   302  3  891717742
# 2       22   377  1  878887116
# 3      244    51  2  880606923
# 4      166   346  1  886397596
# ...    ...   ... ..        ...
# 99995  880   476  3  880175444
# 99996  716   204  5  879795543
# 99997  276  1090  1  874795795
# 99998   13   225  2  882399156
# 99999   12   203  3  879959583
#
# [100000 rows x 4 columns]

# %%
data_user.columns = ["userid", "movieid", "rating", "timestamp"]

# %%
data_user['timestamp'] = pd.to_datetime(data_user['timestamp'], unit = 's')

# %%
data_user
# Out:
#        userid  movieid  rating           timestamp
# 0         196      242       3 1997-12-04 15:55:49
# 1         186      302       3 1998-04-04 19:22:22
# 2          22      377       1 1997-11-07 07:18:36
# 3         244       51       2 1997-11-27 05:02:03
# 4         166      346       1 1998-02-02 05:33:16
# ...       ...      ...     ...                 ...
# 99995     880      476       3 1997-11-22 05:10:44
# 99996     716      204       5 1997-11-17 19:39:03
# 99997     276     1090       1 1997-09-20 22:49:55
# 99998      13      225       2 1997-12-17 22:52:36
# 99999      12      203       3 1997-11-19 17:13:03
#
# [100000 rows x 4 columns]

# %%
user_item_data = data_user.pivot(index='userid', columns='movieid', values='rating').fillna(0)

# %%
pairwise_distances(user_item_data, metric='euclidean')
# Out:
# array([[ 0.        , 65.2533524 , 65.91661399, ..., 63.17436189,
#         67.74215822, 61.8950725 ],
#        [65.2533524 ,  0.        , 35.62302626, ..., 33.24154028,
#         44.71017781, 53.24471805],
#        [65.91661399, 35.62302626,  0.        , ..., 28.10693865,
#         41.88078318, 51.6139516 ],
#        ...,
#        [63.17436189, 33.24154028, 28.10693865, ...,  0.        ,
#         41.32795664, 49.2138192 ],
#        [67.74215822, 44.71017781, 41.88078318, ..., 41.32795664,
#          0.        , 55.13619501],
#        [61.8950725 , 53.24471805, 51.6139516 , ..., 49.2138192 ,
#         55.13619501,  0.        ]], shape=(943, 943))

# %%
user_user_similiraty = pd.DataFrame(pairwise_distances(user_item_data, metric='euclidean'), columns = user_list, index= user_list)

# %%
user_user_similiraty
# Out:
#            1          2          3          4          5          6    \
# 1     0.000000  65.253352  65.916614  65.360539  61.147363  63.348244
# 2    65.253352   0.000000  35.623026  33.970576  50.009999  55.812185
# 3    65.916614  35.623026   0.000000  25.238859  47.222876  57.775427
# 4    65.360539  33.970576  25.238859   0.000000  46.701178  57.645468
# 5    61.147363  50.009999  47.222876  46.701178   0.000000  60.728906
# ..         ...        ...        ...        ...        ...        ...
# 939  66.775744  37.828561  37.443290  36.972963  50.219518  59.799666
# 940  62.369865  42.355637  40.236799  39.242834  49.040799  54.415071
# 941  63.174362  33.241540  28.106939  26.814175  43.794977  55.533774
# 942  67.742158  44.710178  41.880783  40.853396  52.516664  56.178288
# 943  61.895073  53.244718  51.613952  50.685304  52.383203  61.692787
#
#            7          8          9          10   ...        934        935  \
# ...

# %%
user_user_similiraty = user_user_similiraty.sort_values(ascending= True, by=1)

# %%
user_user_similiraty.iloc[1:,0].head(5)
# Out:
# 738    55.063600
# 521    55.235858
# 933    55.614746
# 715    57.070132
# 44     57.402091
# Name: 1, dtype: float64

# %%
user_list = list(set(data_user.userid))

# %%
movies_list = list(set(data_user.movieid))

# %%
user_1 = set(data_user.loc[data_user['userid'] == 1,'movieid'])

# %%
user_738 = set(data_user.loc[data_user['userid'] == 738,'movieid'])

# %%
reco = user_738.difference(user_1)

# %%
data_movies = pd.read_csv(r'C:\Users\sneha\anaconda assignment\excel\u .item',delimiter = '\|', header = None, encoding="ISO-8859-1")
# Out:
# C:\Users\sneha\AppData\Local\Temp\ipykernel_21308\3513001335.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   data_movies = pd.read_csv(r'C:\Users\sneha\anaconda assignment\excel\u .item',delimiter = '\|', header = None, encoding="ISO-8859-1")

# %%
data_movies = data_movies.iloc[:,:2]

# %%
data_movies.columns = ['movieid','movie_name']

# %%
data_movies
# Out:
#       movieid                                 movie_name
# 0           1                           Toy Story (1995)
# 1           2                           GoldenEye (1995)
# 2           3                          Four Rooms (1995)
# 3           4                          Get Shorty (1995)
# 4           5                             Copycat (1995)
# ...       ...                                        ...
# 1677     1678                          Mat' i syn (1997)
# 1678     1679                           B. Monkey (1998)
# 1679     1680                       Sliding Doors (1998)
# 1680     1681                        You So Crazy (1994)
# 1681     1682  Scream of Stone (Schrei aus Stein) (1991)
#
# [1682 rows x 2 columns]

# %%
list(reco)[0:5]
# Out:
# [385, 517, 393, 650, 651]

# %%
data_movies.loc[data_movies['movieid'].isin(list(reco)[0:5]),['movie_name']]
# Out:
#                                           movie_name
# 384                                 True Lies (1994)
# 392                            Mrs. Doubtfire (1993)
# 516                                 Manhattan (1979)
# 649  Seventh Seal, The (Sjunde inseglet, Det) (1957)
# 650                                     Glory (1989)

# %%
item_user_data = data_user.pivot(index='movieid', columns='userid', values='rating').fillna(0)

# %%
pairwise_distances(item_user_data, metric='euclidean')
# Out:
# array([[ 0.        , 77.72387021, 80.07496488, ..., 84.79976415,
#         84.68766144, 84.68766144],
#        [77.72387021,  0.        , 42.17819342, ..., 38.36665219,
#         38.19685851, 38.19685851],
#        [80.07496488, 42.17819342,  0.        , ..., 31.0322413 ,
#         31.11269837, 30.82207001],
#        ...,
#        [84.79976415, 38.36665219, 31.0322413 , ...,  0.        ,
#          3.60555128,  3.60555128],
#        [84.68766144, 38.19685851, 31.11269837, ...,  3.60555128,
#          0.        ,  4.24264069],
#        [84.68766144, 38.19685851, 30.82207001, ...,  3.60555128,
#          4.24264069,  0.        ]], shape=(1682, 1682))

# %%
movie_movie_similarity = pd.DataFrame(pairwise_distances(item_user_data, metric='euclidean'), columns = movies_list , index= movies_list)

# %%
movie_movie_similarity = movie_movie_similarity.sort_values(ascending= True, by=1)

# %%
movie_movie_similarity.iloc[1:,0].head(5)
# Out:
# 121    63.529521
# 405    65.764732
# 117    65.840717
# 151    66.835619
# 118    67.535176
# Name: 1, dtype: float64

# %%
movie_1 = set(data_user.loc[data_user['movieid'] == 1,'userid'])

# %%
movie_121 = set(data_user.loc[data_user['movieid'] == 121,'userid'])

# %%
roc2 = (movie_121.difference(movie_1))

# %%
data_user.loc[data_user['userid'].isin(list(roc2)[0:5]),['userid']]
# Out:
#        userid
# 2          22
# 39          7
# 88         11
# 139         7
# 187         7
# ...       ...
# 98173       7
# 98452      14
# 98485      22
# 98732       7
# 98734      22
#
# [832 rows x 1 columns]

# %%
for i in [1,5,10]:
  movie_list = movie_movie_similarity[i].sort_values()[1:6].index
  print('top 5 movies for movie',i)
  print(data_movies.loc[data_movies['movieid'].isin(movie_list),['movie_name']])
  print('-------------------------')
# Out:
# top 5 movies for movie 1
#                                        movie_name
# 116                              Rock, The (1996)
# 117                                Twister (1996)
# 120                 Independence Day (ID4) (1996)
# 150  Willy Wonka and the Chocolate Factory (1971)
# 404                    Mission: Impossible (1996)
# -------------------------
# top 5 movies for movie 5
#                                   movie_name
# 550                 Lord of Illusions (1995)
# 768                             Congo (1995)
# 778                         Drop Zone (1994)
# 815   Candyman: Farewell to the Flesh (1995)
# 1470                         Hideaway (1995)
# -------------------------
# top 5 movies for movie 10
#                          movie_name
# 129              Kansas City (1996)
# 717   In the Bleak Midwinter (1995)
# 969             Hear My Song (1991)
# 1055                  Cronos (1992)
# 1114           Twelfth Night (1996)
# -------------------------

# %%
for i in [1,5,10]:
  user_list = user_user_similiraty.iloc[1:,i].sort_values(ascending= True).iloc[0:5].index
  print('top 5 user for user',i)
  print(data_user.loc[data_user['userid'].isin(user_list),['userid']].drop_duplicates())
  print('---------------')
# Out:
# top 5 user for user 1
#        userid
# 549       131
# 700         2
# 2005      266
# 43998     701
# 67397     926
# ---------------
# top 5 user for user 5
#        userid
# 9           6
# 295       123
# 1939      321
# 29789     553
# 65993     929
# ---------------
# top 5 user for user 10
#        userid
# 88         11
# 325       187
# 696       208
# 3732      163
# 32166     575
# ---------------

# %%
for i in [10,20,30,50,100]:
    print('Recommended Movies for user ',i)
    top_1_similar_user = user_user_similiraty[i].sort_values()[1:2].index
    print('Top 1 Similar users for user ',i, 'are: ', top_1_similar_user)
    for j in range(0,len(top_1_similar_user)):
        u1st = i
        u2nd = top_1_similar_user[j]
        print('Movie to recommend to user ',u1st, 'on the basis on user ',u2nd)
        sm_1stu = set(data_user[data_user['userid']==u1st]['movieid'].values)
        sm_2ndu = set(data_user[data_user['userid']==u2nd]['movieid'].values)
        movie_list = list(sm_2ndu - sm_1stu)
        print(movie_list)
        print(data_movies[data_movies['movieid'].isin(movie_list)]['movie_name'])
    print("---------------------")
# Out:
# Recommended Movies for user  10
# Top 1 Similar users for user  10 are:  Index([321], dtype='int64')
# Movie to recommend to user  10 on the basis on user  321
# [np.int64(514), np.int64(515), np.int64(1028), np.int64(131), np.int64(647), np.int64(8), np.int64(523), np.int64(14), np.int64(526), np.int64(143), np.int64(19), np.int64(20), np.int64(659), np.int64(1050), np.int64(30), np.int64(287), np.int64(419), np.int64(1194), np.int64(428), np.int64(45), np.int64(173), np.int64(942), np.int64(1331), np.int64(52), np.int64(61), np.int64(190), np.int64(193), np.int64(1101), np.int64(207), np.int64(83), np.int64(212), np.int64(213), np.int64(86), np.int64(87), np.int64(215), np.int64(89), np.int64(730), np.int64(855), np.int64(607), np.int64(224), np.int64(736), np.int64(863), np.int64(485), np.int64(614), np.int64(1126), np.int64(491), np.int64(494), np.int64(631), np.int64(633), np.int64(507), np.int64(382)]
# 7                                             Babe (1995)
# ...
